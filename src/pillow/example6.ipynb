# %%
from PIL import  Image

model1 = Image.open("../../images/Iranian_model.webp")

model1.show()

# %%
## You can rotate images

model1.rotate(180).show()

# %%
## The original size of the image

model1.size
# Out:
# (1000, 1201)

# %%
## Make a thumbnail of the image (changes the original image instance)

THUMB_NAIL_SIZE = (128, 128)
model1.thumbnail(THUMB_NAIL_SIZE)
model1.show()

# %%
model1
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=107x128>
